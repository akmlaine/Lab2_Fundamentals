# %%
# APPENDIX ADDITIONAL EXERCISES
# EXERCISE 1

ENGINEER = "MALITAO"
STUDENT_ID = "TUPM-26-1135"
SEED_NUM = int(STUDENT_ID[-1])

print("System Initialized for:", ENGINEER)
print("Algorithmic Seed Value:", SEED_NUM)


# 2. GENERATE SENSOR DATA
sensor_data = []

for letter in ENGINEER:
    value = ord(letter) + SEED_NUM
    sensor_data.append(value)

# Fixed number of sensor readings
sensor_data = sensor_data[:5]

print("Generated Sensor Data:", sensor_data)


# 3. OPERATING RANGE
limit = (SEED_NUM * 10) + 20

print("Safety Limit:", limit)


# 4. RECEIVE AND VALIDATE READINGS
valid_readings = []
invalid_readings = []
classification_results = []

for i in range(5):

    user_input = input("Enter Sensor Reading " + str(i + 1) + ": ")

    try:
        reading = int(user_input)

        # Validate the reading
        if reading < 0:
            print("Invalid Reading")
            invalid_readings.append(user_input)

        else:
            print("Valid Reading")
            valid_readings.append(reading)

            # 5. CLASSIFY VALID READINGS
            if reading < 5:
                result = "LOW SIGNAL"

            elif reading <= limit:
                result = "NOMINAL"

            else:
                result = "OVER LIMIT"

            print("Classification:", result)
            classification_results.append(result)

    except ValueError:
        print("Invalid Input: Please enter a number.")
        invalid_readings.append(user_input)


# 6. FINAL SUMMARY
print("------ FINAL OUTPUT ------")

print("Generated Sensor Data:", sensor_data)
print("Valid Results:", valid_readings)
print("Invalid Results:", invalid_readings)
print("Classification Results:", classification_results)

print("Total Readings:", 5)
print("Total Valid:", len(valid_readings))
print("Total Invalid:", len(invalid_readings))
print("Safety Limit:", limit)

print("Execution Log:")
if len(valid_readings) + len(invalid_readings) == 5:
    print("All readings processed successfully.")
else:
    print("Some readings were not processed correctly.")
# Out:
# System Initialized for: MALITAO
# Algorithmic Seed Value: 5
# Generated Sensor Data: [82, 70, 81, 78, 89]
# Safety Limit: 70
# Valid Reading
# Classification: NOMINAL
# Invalid Input: Please enter a number.
# Valid Reading
# Classification: NOMINAL
# Valid Reading
# Classification: NOMINAL
# Valid Reading
# Classification: NOMINAL
# ------ FINAL OUTPUT ------
# Generated Sensor Data: [82, 70, 81, 78, 89]
# Valid Results: [25, 23, 8, 9]
# Invalid Results: ['alaine']
# Classification Results: ['NOMINAL', 'NOMINAL', 'NOMINAL', 'NOMINAL']
# Total Readings: 5
# Total Valid: 4
# Total Invalid: 1
# Safety Limit: 70
# EXECUTION LOG:
# All readings processed successfully.

# %%
# APPENDIX ADDITIONAL EXERCISES
#  EXERCISE 2

ENGINEER = "MALITAO"
STUDENT_ID = "TUPM-26-1135"
SEED_NUM = int(STUDENT_ID[-1])

print("System Initialized for:", ENGINEER)
print("Seed Number:", SEED_NUM)


# 2. GENERATE SIGNAL
signal = ENGINEER + " " + str(SEED_NUM)

print("Generated Signal:", signal)


# 3. PROCESS AND NORMALIZE SIGNAL
processed_signal = signal.upper()

print("Processed Signal:", processed_signal)


# 4. ANALYZE EACH CHARACTER
letters = 0
numbers = 0
spaces = 0
others = 0

print("------ CHARACTER ANALYSIS ------")

for character in processed_signal:

    if character.isalpha():
        print(character, "- LETTER")
        letters += 1

    elif character.isdigit():
        print(character, "- NUMBER")
        numbers += 1

    elif character.isspace():
        print(character, "- SPACE")
        spaces += 1

    else:
        print(character, "- OTHER")
        others += 1


# 5. SIGNAL CLASSIFICATION
if others > 0:
    classification = "CONTAINS OTHER CHARACTERS"

elif numbers > 0:
    classification = "ALPHANUMERIC SIGNAL"

else:
    classification = "LETTER SIGNAL"


# 6. DIAGNOSTIC REPORT
print("===== DIAGNOSTIC REPORT =====")
print("Generated Signal:", signal)
print("Processed Signal:", processed_signal)

print("Character Analysis:")
print("Letters:", letters)
print("Numbers:", numbers)
print("Spaces:", spaces)
print("Other Characters:", others)

print("Signal Classification:", classification)

if letters + numbers + spaces + others == len(processed_signal):
    print("Execution Log: Successfully completed.")
else:
    print("Execution Log: Processing incomplete.")
# Out:
# System Initialized for: MALITAO
# Seed Number: 5
# Generated Signal: MALITAO 5
# Processed Signal: MALITAO 5
# ------ CHARACTER ANALYSIS ------
# M - LETTER
# A - LETTER
# L - LETTER
# I - LETTER
# T - LETTER
# A - LETTER
# O - LETTER
#   - SPACE
# 5 - NUMBER
# ===== DIAGNOSTIC REPORT =====
# Generated Signal: MALITAO 5
# Processed Signal: MALITAO 5
# Character Analysis:
# Letters: 7
# Numbers: 1
# Spaces: 1
# Other Characters: 0
# Signal Classification: ALPHANUMERIC SIGNAL
# Execution Log: Successfully completed.

# %%
# APPENDIX ADDITIONAL EXERCISES
#  EXERCISE 3 

ENGINEER = "MALITAO"
STUDENT_ID = "TUPM-26-1135"
SEED_NUM = int(STUDENT_ID[-1])

print("System Initialized for:", ENGINEER)
print("Seed Number:", SEED_NUM)


# 2. GENERATE PASSWORD
password = ENGINEER + str(SEED_NUM)

# Normalize password
password = password.upper()

print("Generated Password:", password)


# 3. GENERATE ATTEMPT LIMIT
attempt_limit = SEED_NUM + 3

print("Attempt Limit:", attempt_limit)


# 4. AUTHENTICATION
attempts = 0
access_granted = False

while attempts < attempt_limit:

    user_password = input("Enter Password: ")

    user_password = user_password.strip().upper()

    attempts += 1

    if user_password == password:
        print("Access Granted!")
        access_granted = True
        break

    else:
        print("Incorrect Password.")
        print("Attempts Made:", attempts)


# 5. FINAL SYSTEM STATE
if access_granted:
    access_result = "ACCESS GRANTED"
    system_state = "UNLOCKED"

else:
    access_result = "ACCESS DENIED"
    system_state = "LOCKED"

print("Execution Log:")
if access_granted:
    print("  Access granted on attempt", attempts)
else:
    print("  Access denied after", attempts, "attempts")

# 6. FINAL OUTPUT
print("===== FINAL OUTPUT =====")
print("Generated Password:", password)
print("Attempt Limit:", attempt_limit)
print("Attempts Made:", attempts)
print("Access Result:", access_result)
print("Final System State:", system_state)
# Out:
# System Initialized for: MALITAO
# Seed Number: 5
# Generated Password: MALITAO5
# Attempt Limit: 8
# Incorrect Password.
# Attempts Made: 1
# Incorrect Password.
# Attempts Made: 2
# Access Granted!
# Execution Log:
#   Access granted on attempt 3
# ===== FINAL OUTPUT =====
# Generated Password: MALITAO5
# Attempt Limit: 8
# Attempts Made: 3
# Access Result: ACCESS GRANTED
# Final System State: UNLOCKED
